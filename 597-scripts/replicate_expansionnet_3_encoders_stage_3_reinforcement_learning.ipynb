# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/ExpansionNet_v2/
# Out:
# /content/drive/.shortcut-targets-by-id/1C62olCXTaJYttKJ3KQoGIkKlMOX0JCSx/ExpansionNet_v2

# %%
# %cat requirements.txt
# Out:
# # NOTE: Installing whatever version of torch, torchvision, h5py, Pillow
# # fit your machine should work in most cases. Here is reported one possible
# # working configuration but these specific versions are not mandatory.
#
# h5py==3.8.0
# # numpy==1.21.6
# # Pillow==9.0.1
# Pillow==10.2.0
# torch==1.12.1+cu113
# torchvision==0.10.0+cu111

# %%
# %pip install h5py numpy Pillow torch torchvision

# %%
# !cp '/content/drive/MyDrive/dataHm4.zip' /content/

# %%
# !unzip '/content/dataHm4.zip' -d '/content/data_hw4/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data_hw4/dataHm4/data/train2014/COCO_train2014_000000540831.jpg
#   inflating: /content/data_hw4/dataHm4/data/train2014/COCO_train2014_000000540833.jpg
#   inflating: /content/data_hw4/dataHm4/data/train2014/COCO_train2014_000000540838.jpg
#   inflating: /content/data_hw4/dataHm4/data/train2014/COCO_train2014_000000540840.jpg
#   inflating: /content/data_hw4/dataHm4/data/train2014/COCO_train2014_000000540843.jpg
#   inflating: /content/data_hw4/dataHm4/data/train2014/COCO_train2014_000000540844.jpg
#   inflating: /content/data_hw4/dataHm4/data/train2014/COCO_train2014_000000540846.jpg
#   inflating: /content/data_hw4/dataHm4/data/train2014/COCO_train2014_000000540848.jpg
#   inflating: /content/data_hw4/dataHm4/data/train2014/COCO_train2014_000000540858.jpg
#   inflating: /content/data_hw4/dataHm4/data/train2014/COCO_train2014_000000540863.jpg
# ...

# %%
# !ls github_ignore_material/raw_data
# Out:
# dataset_coco.json  swin_large_patch4_window12_384_22k.pth

# %%
import os

a = os.listdir("/content/data_hw4/dataHm4/data/train2014")

# %%
len(a)
# Out:
# 10000

# %%
pwd
# Out:
# '/content/drive/.shortcut-targets-by-id/1C62olCXTaJYttKJ3KQoGIkKlMOX0JCSx/ExpansionNet_v2'

# %%
# !ls /content/drive/MyDrive/*.pth
# Out:
# /content/drive/MyDrive/rf_model_140.4.pth

# %%
mkdir /content/drive/MyDrive/ExpansionNet_v2/github_ignore_material/saves/

# %%
ls /content/drive/MyDrive/ExpansionNet_v2/github_ignore_material/
# Out:
# raw_data/  saves/

# %%
# !python data_generator.py \
    --save_model_path /content/drive/.shortcut-targets-by-id/1C62olCXTaJYttKJ3KQoGIkKlMOX0JCSx/ExpansionNet_v2/github_ignore_material/saves/checkpoint_2024-12-04-20:07:30_epoch1it4065bs16_xe_.pth \
    --output_path /content/drive/.shortcut-targets-by-id/1C62olCXTaJYttKJ3KQoGIkKlMOX0JCSx/ExpansionNet_v2/github_ignore_material/raw_data/features.hdf5 \
    --images_path /content/data_hw4/dataHm4/data/ \
    --captions_path /content/filtered_data.json
# Out:
# ...
# Features path: None
# Initializing dataset...  Num train images: 13004
# Num val images: 490
# Num test images: 506
# tot tokens 10864 less than 5: 6996 remaining: 3868
# There are 3870 vocabs in dict
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
# !python train.py --N_enc 3 --N_dec 3  \
    --model_dim 512 --optim_type radam --seed 775533  --sched_type custom_warmup_anneal  \
    --warmup 1 --lr 1e-4 --anneal_coeff 0.8 --anneal_every_epoch 1 --enc_drop 0.1 \
    --dec_drop 0.1 --enc_input_drop 0.1 --dec_input_drop 0.1 --drop_other 0.1  \
    --batch_size 24 --num_accum 2 --num_gpus 1 --ddp_sync_port 11317 --eval_beam_sizes [5]  \
    --save_path /content/drive/.shortcut-targets-by-id/1C62olCXTaJYttKJ3KQoGIkKlMOX0JCSx/ExpansionNet_v2/github_ignore_material/saves/ --save_every_minutes 60 --how_many_checkpoints 1  \
    --is_end_to_end False --partial_load True \
    --features_path /content/drive/.shortcut-targets-by-id/1C62olCXTaJYttKJ3KQoGIkKlMOX0JCSx/ExpansionNet_v2/github_ignore_material/raw_data/features.hdf5 \
    --body_save_path /content/drive/.shortcut-targets-by-id/1C62olCXTaJYttKJ3KQoGIkKlMOX0JCSx/ExpansionNet_v2/github_ignore_material/saves/checkpoint_2024-12-04-20:07:30_epoch1it4065bs16_xe_.pth \
    --print_every_iter 4000 --eval_every_iter 99999 \
    --captions_path /content/filtered_data.json \
    --reinforce True --num_epochs 9
# Out:
# seed: 775533
# train batch_size: 24
# num_accum: 2
# ddp_sync_port: 11317
# save_path: /content/drive/.shortcut-targets-by-id/1C62olCXTaJYttKJ3KQoGIkKlMOX0JCSx/ExpansionNet_v2/github_ignore_material/saves/
# num_gpus: 1
# Features path: /content/drive/.shortcut-targets-by-id/1C62olCXTaJYttKJ3KQoGIkKlMOX0JCSx/ExpansionNet_v2/github_ignore_material/raw_data/features.hdf5
# Features path provided, images are provided in form of features.
# Initializing dataset...  Num train images: 13004
# Num val images: 490
# Num test images: 506
# tot tokens 10864 less than 5: 6996 remaining: 3868
# There are 3870 vocabs in dict
# Max sequence length: 69
# y vocabulary size: 3870
# Using -  1  processes / GPUs!
# Requested num GPUs: 1
# GPU: 0] Process 0 working...
# Reinforcement learning Mode
# 0] data.coco_dataloader) Dataset epoch initialization 0.013015985488891602 s elapsed
# 0] data.coco_dataloader) How many batches 541
# ...
